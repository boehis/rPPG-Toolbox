# %% [markdown]
# # Model Output Data Visualization

# %% [markdown]
# ### Read Me

# %% [markdown]
# This notebook vizualizes model outputs for supervised neural methods from the rPPG Toolbox. To use this notebook follow the following steps:
#
# * STEP 1: Specify the `TEST.OUTPUT_SAVE_DIR` field in the `.yaml` config file of a neural method experiment.
# * STEP 2: Run the neural method experiment. A `.pickle` file containing the test-data predictions and labels will be created in `TEST.OUTPUT_SAVE_DIR`.
# * STEP 3: Add the path to the `pickle` file in the `TODO: Variable to Set` section as `data_out_path`.
# * STEP 4: Add values for `trial_idx` (a value between 0 and the `Num Trials` print in the previous cell), `chunk_size` (number of samples to plot out), `chunk_num` (the chunk of size `chunk_size` in the signal). We suggest using the defaults at first.
# * STEP 5: Run all cells. The predicted output, plotted against the ground truth ppg waveform, will be plotted in the final cell

# %% [markdown]
# ### Imports

# %%
# !pip install natsort
# !pip install scipy
# !pip install natsort
# !pip install ipywidgets

import cv2
import pickle
import numpy as np
import os
import matplotlib.pyplot as plt
import re

import torch

import numpy as np
# import ipywidgets as widgets
from IPython.display import display, clear_output
from natsort import natsorted
import os
import scipy
from scipy.sparse import spdiags
from scipy.signal import butter
import math
from scipy import linalg
from scipy import signal
from scipy import sparse

# %% [markdown]
# ### Helper Functions

# %%
# HELPER FUNCTIONS

def _reform_data_from_dict(data, flatten=True):
    """Helper func for calculate metrics: reformat predictions and labels from dicts. """
    sort_data = sorted(data.items(), key=lambda x: x[0])
    sort_data = [i[1] for i in sort_data]
    sort_data = torch.cat(sort_data, dim=0)

    if flatten:
        sort_data = np.reshape(sort_data.cpu(), (-1))
    else:
        sort_data = np.array(sort_data.cpu())

    return sort_data

def _process_signal(signal, fs=30, diff_flag=True):
    # Detrend and filter
    use_bandpass = True
    if diff_flag:  # if the predictions and labels are 1st derivative of PPG signal.
        gt_bvp = _detrend(np.cumsum(signal), 100)
    else:
        gt_bvp = _detrend(signal, 100)
    if use_bandpass:
        # bandpass filter between [0.75, 2.5] Hz
        # equals [45, 150] beats per min
        [b, a] = butter(1, [0.5 / fs * 2, 2.5 / fs * 2], btype='bandpass')
        signal = scipy.signal.filtfilt(b, a, np.double(signal))
    return signal

def _detrend(input_signal, lambda_value):
    """Detrend PPG signal."""
    signal_length = input_signal.shape[0]
    # observation matrix
    H = np.identity(signal_length)
    ones = np.ones(signal_length)
    minus_twos = -2 * np.ones(signal_length)
    diags_data = np.array([ones, minus_twos, ones])
    diags_index = np.array([0, 1, 2])
    D = spdiags(diags_data, diags_index,
                (signal_length - 2), signal_length).toarray()
    detrended_signal = np.dot(
        (H - np.linalg.inv(H + (lambda_value ** 2) * np.dot(D.T, D))), input_signal)
    return detrended_signal

# %% [markdown]
# ### TODO: Variables To Set

# %%
data_out_path = "../../runs/tscan/AriaPPG_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_tscan_outputs.pickle"
data_out_path = "../../runs/deepphys_pxt1headstat/AriaPPG_SizeW72_SizeH72_ClipLength180_DataTypeDiffNormalized_Standardized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_deepphys_outputs.pickle"
data_out_path = '../../runs/infer_configs/UBFC-rPPG_AriaPPG_PHYSNET_BASIC/pxtx/AriaPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/UBFC-rPPG_PhysNet_DiffNormalized_AriaPPG_outputs.pickle'
data_out_path = '../../runs/infer_configs/PURE_AriaPPG_PHYSNET_BASIC/pxt1stat/first_frame_D128/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/PURE_PhysNet_DiffNormalized_AriaPPG_outputs.pickle'
# data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/f_first/AriaPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
# data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/f_first_raw/AriaPPG_SizeW72_SizeH72_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
# data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/raw/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/raw/shifted/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/raw/pseudo/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/raw/shifted_small/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '../../runs/train_configs/PHYSNET/pxt1stat/raw/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeRaw_DataAugNone_LabelTypeRaw_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '/cluster/scratch/boehis/runs/train_configs/PhysFormer/median/loso_cv_finetune/fold_0/AriaPPG_SizeW128_SizeH128_ClipLength160_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physformer_outputs.pickle'

data_out_path = '/cluster/scratch/boehis/runs/train_configs/PhysNet/median/loso_cv_retrain/fold_18/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'
data_out_path = '/cluster/scratch/boehis/runs/train_configs/PhysNet/median/multimodal/cross_attention_8_imu/fold_18/AriaPPG_SizeW128_SizeH128_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse/saved_test_outputs/AriaPPG_AriaPPG_physnet_outputs.pickle'

trial_idx = 8
chunk_size = 128 # size of chunk to visualize: -1 will plot the entire signal
chunk_num = 1

# %% [markdown]
# ### Read Data, and Extract Trials List

# %%
# Read in data and list subjects
with open(data_out_path, 'rb') as f:
    data = pickle.load(f)
    
# List of all video trials
trial_list = list(data['predictions'].keys())
print('Num Trials', len(trial_list))
# Out:
# Num Trials 10

# %%
# Reform label and prediction vectors from multiple trial chunks
prediction = np.array(_reform_data_from_dict(data['predictions'][trial_list[trial_idx]]))
label = np.array(_reform_data_from_dict(data['labels'][trial_list[trial_idx]]))

# Read in meta-data from pickle file
fs = data['fs'] # Video Frame Rate
label_type = data['label_type'] # PPG Signal Transformation: `DiffNormalized` or `Standardized`
diff_flag = (label_type == 'DiffNormalized')

if chunk_size == -1:
    chunk_size = len(prediction)
    chunk_num = 0

# Process label and prediction signals
prediction = _process_signal(prediction, fs, diff_flag=diff_flag)
label = _process_signal(label, fs, diff_flag=diff_flag)
start = (chunk_num)*chunk_size
stop = (chunk_num+1)*chunk_size
samples = stop - start
x_time = np.linspace(0, samples/fs, num=samples)

plt.figure(figsize=(10,5))
plt.plot(x_time, prediction[start:stop] / np.max(prediction[start:stop]), color='r')
plt.plot(x_time, label[start:stop] / np.max(label[start:stop]), color='black')
plt.title('Trial: ' + trial_list[trial_idx])
plt.legend(['Predictions', 'Labels'])
plt.xlabel('Time (s)');
# Out:
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "edgecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
from scipy.signal import welch
# Define function to plot frequency domain signals
def plot_frequency_domain(signal, ref_signal, fs, color, label):
    freqs_signal, psd_signal = welch(signal, fs)
    freqs_ref, psd_ref = welch(ref_signal, fs)
    psd_signal = psd_signal / np.max(psd_signal)
    psd_ref = psd_ref / np.max(psd_ref)
    plt.figure(figsize=(10, 5))
    plt.plot(freqs_signal, psd_signal, color=color, label=label)
    plt.plot(freqs_ref, psd_ref, color='k', label='Reference')
    plt.xlim([0, 5])  # limit to 0-5 Hz for clarity
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power Spectral Density')
    plt.legend()
    plt.title('Frequency Domain Comparison')
    plt.show()

# Plot frequency domain signals for predictions and labels
plot_frequency_domain(prediction[start:stop], label[start:stop], fs, 'r', 'Predictions')
# Out:
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/scipy/signal/_spectral_py.py:600: UserWarning: nperseg = 256 is greater than input length  = 128, using nperseg = 128
#   freqs, _, Pxy = _spectral_helper(x, y, fs, window, nperseg, noverlap,
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# /cluster/software/stacks/2024-05/python-cuda/3.11.6/lib/python3.11/site-packages/IPython/core/pylabtools.py:170: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "facecolor" which is no longer supported as of 3.3 and will become an error two minor releases later
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
data['predictions']['headP002T1'][0].shape
# Out:
# torch.Size([180, 1])

# %%
prediction = data['predictions']['headP002T1'][1].flatten().numpy()
label = data['labels']['headP002T1'][1].flatten().numpy()

# %%
prediction_p = _process_signal(prediction, 30, diff_flag=True)
label_p = _process_signal(label, 30, diff_flag=True)

# %%
plt.plot(prediction)

# %%
plt.plot(label)
plt.plot(np.cumsum(label))

# %%
data.keys()
# Out:
# dict_keys(['predictions', 'labels', 'label_type', 'fs'])

# %%
data['labels'].keys()
# Out:
# dict_keys(['statP016T1', 'statP017T1', 'statP018T1', 'statP019T1', 'statP020T1', 'statP021T1', 'statP023T1', 'statP024T1'])

# %%
path = '/cluster/scratch/boehis/AriaPPG_prep_f_median_128/prep/AriaPPG_SizeW72_SizeH72_ClipLength128_DataTypeDiffNormalized_DataAugNone_LabelTypeDiffNormalized_Crop_faceFalse_BackendHC_Large_boxTrue_Large_size1.5_Dyamic_DetFalse_det_len30_Median_face_boxFalse'

label = data['labels']['statP017T1'][0]
label_original = np.load(os.path.join(path,'statP017T1_label0.npy'))
label = np.cumsum(label)
label_original = np.cumsum(label_original)
plt.plot(label)
plt.plot(label_original)
